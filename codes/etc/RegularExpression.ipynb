# %%
import re

line = "Cats are smarter than dogs"

matchObj = re.match( r'(.*) are (.*?) .*', line, re.M|re.I)

if matchObj:
   print ("matchObj.group() : ", matchObj.group())
   print ("matchObj.group(1) : ", matchObj.group(1))
   print ("matchObj.group(2) : ", matchObj.group(2))
else:
   print ("No match!!")
# Out:
# matchObj.group() :  Cats are smarter than dogs
# matchObj.group(1) :  Cats
# matchObj.group(2) :  smarter

# %%
matchObj
# Out:
# <_sre.SRE_Match object; span=(0, 26), match='Cats are smarter than dogs'>

# %%
import re

line = "Cats are smarter than dogs";

searchObj = re.search( r'(.*) are (.*?) .*', line, re.M|re.I)

if searchObj:
   print ("searchObj.group() : ", searchObj.group())
   print ("searchObj.group(1) : ", searchObj.group(1))
   print ("searchObj.group(2) : ", searchObj.group(2))
else:
   print ("Nothing found!!")
# Out:
# searchObj.group() :  Cats are smarter than dogs
# searchObj.group(1) :  Cats
# searchObj.group(2) :  smarter

# %%
import re

phone = "2004-959-559 # This is Phone Number"

searchObj = re.search( r'[\d]*-[\d]*-[\d]*', phone)

if searchObj:
   print ("searchObj.group() : ", searchObj.group())
# Out:
# searchObj.group() :  2004-959-559

# %%
searchObj, type(searchObj.group())
# Out:
# (<_sre.SRE_Match object; span=(0, 12), match='2004-959-559'>, str)

# %%
import re
phone = "2004-959-559 # This is Phone Number"
num = re.sub(r'#.*$', "", phone)
print ("Phone Num : ", num)
num = re.sub(r'\D', "", phone)    
print ("Phone Num : ", num)
# Out:
# Phone Num :  2004-959-559
# Phone Num :  2004959559

# %%
phone = "2004-959-559 # This is Phone Number"
num = re.sub(r'[\d]', "", phone)
num
# Out:
# '-- # This is Phone Number'
