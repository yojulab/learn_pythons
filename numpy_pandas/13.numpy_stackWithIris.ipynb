# %% [markdown]
# #첫번째

# %% [markdown]
# ##첫번째 - 1

# %% [markdown]
# 아이리스 형태소 분석

# %% [markdown]
# # road iris from sklearn

# %%
import numpy as np
from sklearn import datasets

# %%
iris = datasets.load_iris()
print(type(iris), iris['DESCR'])

# %%
data = datasets.load_breast_cancer()
data['DESCR']
# Out:
# '.. _breast_cancer_dataset:\n\nBreast cancer wisconsin (diagnostic) dataset\n--------------------------------------------\n\n**Data Set Characteristics:**\n\n    :Number of Instances: 569\n\n    :Number of Attributes: 30 numeric, predictive attributes and the class\n\n    :Attribute Information:\n        - radius (mean of distances from center to points on the perimeter)\n        - texture (standard deviation of gray-scale values)\n        - perimeter\n        - area\n        - smoothness (local variation in radius lengths)\n        - compactness (perimeter^2 / area - 1.0)\n        - concavity (severity of concave portions of the contour)\n        - concave points (number of concave portions of the contour)\n        - symmetry \n        - fractal dimension ("coastline approximation" - 1)\n\n        The mean, standard error, and "worst" or largest (mean of the three\n        largest values) of these features were computed for each image,\n        resulting in 30 features.  For instanc
# ...

# %%
data = datasets.load_boston()
data.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %% [markdown]
# #split

# %% [markdown]
# ##hsplit

# %%
irisdata_hsplit = np.hsplit(irisdata,irisdata.shape[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-8d6fd4f6f21c> in <module>()
# ----> 1 irisdata_hsplit = np.hsplit(irisdata,irisdata.shape[1])
#
# NameError: name 'irisdata' is not defined

# %%
irisdata = iris['data']
irisdata.shape, type(irisdata)

# %%
len(irisdata_hsplit), irisdata_hsplit[0]

# %% [markdown]
# ##hstack

# %%
irisdata_hstack = np.hstack((irisdata_hsplit[0], irisdata_hsplit[2]))
irisdata_hstack

# %%
irisdata_vsplit = np.vsplit(irisdata,irisdata.shape[0])
len(irisdata_vsplit)

# %%
irisdata_vstack = np.vstack((irisdata_vsplit[5], irisdata_vsplit[8], irisdata_vsplit[10]))
len(irisdata_vstack)

# %%
irisdata_vstack

# %%
irisdata_vstack_mask = np.vstack((irisdata_vsplit > 4.0))
len(irisdata_vstack)

# %% [markdown]
# #Useful numpy function

# %% [markdown]
# ##sqrt

# %%
irisdata_squrt = np.sqrt(irisdata[:,0])
irisdata_squrt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-0c70c8297c62> in <module>()
# ----> 1 irisdata_squrt = np.sqrt(irisdata[:,0])
#       2 irisdata_squrt
#
# NameError: name 'irisdata' is not defined

# %% [markdown]
# ##rint

# %%
irisdata_rint = np.rint(irisdata)
irisdata_rint

# %% [markdown]
# ## Check Number

# %%
irisdata_isnan = np.isnan(irisdata)
irisdata_isnan
